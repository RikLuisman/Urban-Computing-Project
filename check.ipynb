# %%
import matplotlib.pyplot as plt
from Prithvi_run_inference import read_geotiff

# %%
file_paths = [
    "Output/predicted_t0.tiff",
    "Output/predicted_t1.tiff",
    "Output/predicted_t2.tiff"
]

# %%
img, meta = read_geotiff("Output/predicted_t0.tiff")

plt.imshow(img[0], cmap="gray")  # Display the first band
plt.title(f"Viewing Band 1: predicted_t0.tiff")
plt.colorbar(label="Pixel Value")
plt.axis("off")
plt.show()
